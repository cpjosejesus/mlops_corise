# %% [markdown]
# # Introduction
#
# ### Problem
#
# In the project this week, we will conduct detailed model evaluation, data quality testing and behavioral testing for the news classification model from the week 1 project.
#
# 1. We will look at evaluation metrics beyond overall accuracy and f1 score (per-class metrics, confusion matrix, per-class false positive and false negative errors)
# 2. We will implement bootstrap sampling to measure confidence intervals of model performance metrics
# 3. We will implement behavioral tests using a popular open source library called checklist
# 4. [advanced] Advanced data quality and behavioral tests
#
# ### Deliverables
# 1. Test set per-class accuracy, precision, recall and F-1 score
# 2. Test set confusion matrix, and per-class false positive, false negative errors
# 3. 95% confidence intervals for test set metrics as estimated via bootstrap sampling
# 4. Behavioral tests for the trained news classification model, using checklist.
# 5. [Optional] Advanced data quality and behavioral tests

# %% [markdown]
# ## Step1: Prereqs & Installation
#
# Download & Import all the necessary libraries we need throughout the project.

# %%
# Install all the required dependencies for the project

# !pip install numpy
# !pip install scikit-learn
# !pip install gensim
# !pip install sentence-transformers
# !pip install matplotlib
# !pip install great_expectations
# Out:
# Requirement already satisfied: numpy in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (1.25.0)
# Requirement already satisfied: scikit-learn in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from scikit-learn) (1.25.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: gensim in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from gensim) (1.25.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from gensim) (1.11.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: sentence-transformers in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (4.30.2)
# Requirement already satisfied: tqdm in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: torchvision in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (0.15.2)
# Requirement already satisfied: numpy in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (1.25.0)
# Requirement already satisfied: scikit-learn in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (1.11.1)
# Requirement already satisfied: nltk in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: filelock in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.1)
# Requirement already satisfied: click in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nltk->sentence-transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from torchvision->sentence-transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: matplotlib in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: great_expectations in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (0.17.2)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: Click>=7.1.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (8.1.3)
# Requirement already satisfied: colorama>=0.4.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (41.0.1)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (6.7.0)
# Requirement already satisfied: Ipython>=7.16.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (8.14.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (8.0.6)
# Requirement already satisfied: jinja2>=2.10 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (3.1.2)
# Requirement already satisfied: jsonpatch>=1.22 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (4.17.3)
# Requirement already satisfied: makefun<2,>=1.7.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (1.15.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (3.19.0)
# Requirement already satisfied: mistune>=0.8.4 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (3.0.1)
# Requirement already satisfied: nbformat>=5.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (5.9.0)
# Requirement already satisfied: notebook>=6.4.10 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (6.5.4)
# Requirement already satisfied: packaging in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (23.1)
# Requirement already satisfied: pydantic<2.0,>=1.9.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (1.10.10)
# Requirement already satisfied: pyparsing>=2.4 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (2023.3)
# Requirement already satisfied: requests>=2.20 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (2.31.0)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: scipy>=1.6.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (1.11.1)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (4.7.1)
# Requirement already satisfied: tzlocal>=1.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (5.0.1)
# Requirement already satisfied: urllib3>=1.26 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (2.0.3)
# Requirement already satisfied: numpy>=1.19.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (1.25.0)
# Requirement already satisfied: pandas>=1.1.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from great_expectations) (2.0.3)
# Requirement already satisfied: entrypoints in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from cryptography>=3.2->great_expectations) (1.15.1)
# Requirement already satisfied: zipp>=0.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from importlib-metadata>=1.7.0->great_expectations) (3.15.0)
# Requirement already satisfied: backcall in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.2.0)
# Requirement already satisfied: decorator in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (2.15.1)
# Requirement already satisfied: stack-data in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (4.8.0)
# Requirement already satisfied: appnope in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipywidgets>=7.5.1->great_expectations) (6.23.3)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipywidgets>=7.5.1->great_expectations) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jinja2>=2.10->great_expectations) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonpatch>=1.22->great_expectations) (2.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (0.19.3)
# Requirement already satisfied: fastjsonschema in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbformat>=5.0->great_expectations) (2.17.1)
# Requirement already satisfied: jupyter-core in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbformat>=5.0->great_expectations) (5.3.1)
# Requirement already satisfied: tornado>=6.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (6.3.2)
# Requirement already satisfied: pyzmq>=17 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (25.1.0)
# Requirement already satisfied: argon2-cffi in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (8.3.0)
# Requirement already satisfied: ipython-genutils in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (0.2.0)
# Requirement already satisfied: nbconvert>=5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (7.6.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from notebook>=6.4.10->great_expectations) (1.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from pandas>=1.1.3->great_expectations) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from python-dateutil>=2.8.1->great_expectations) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests>=2.20->great_expectations) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests>=2.20->great_expectations) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from requests>=2.20->great_expectations) (2023.5.7)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ruamel.yaml<0.17.18,>=0.16->great_expectations) (0.2.7)
# Requirement already satisfied: pycparser in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (1.6.7)
# Requirement already satisfied: psutil in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-core->nbformat>=5.0->great_expectations) (3.8.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (2.7.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->Ipython>=7.16.3->great_expectations) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from argon2-cffi->notebook>=6.4.10->great_expectations) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (0.2.2)
# Requirement already satisfied: webencodings in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.4.4)
# Requirement already satisfied: overrides in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (7.3.1)
# Requirement already satisfied: websocket-client in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.1.1)
# Requirement already satisfied: fqdn in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (1.5.1)
# Requirement already satisfied: isoduration in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (20.11.0)
# Requirement already satisfied: uri-template in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from jsonschema>=2.5.1->great_expectations) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages (from isoduration->jsonschema>=2.5.1->great_expectations) (1.2.3)

# %%
# Package imports that will be needed for this project

import numpy as np
import json
from sentence_transformers import SentenceTransformer
from pprint import pprint
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as sklearn_metrics
# Out:
# /Users/josejesuscp/personal/learning/corise/env/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Global Constants

LABEL_SET = [
    'Business',
    'Sci/Tech',
    'Software and Developement',
    'Entertainment',
    'Sports',
    'Health',
    'Toons',
    'Music Feeds'
]

EMBEDDING_MODEL = 'all-mpnet-base-v2'
DATA_URL = 'https://corise-mlops.s3.us-west-2.amazonaws.com/project2/agnews.zip'

# %% [markdown]
# ## Step 2: Download and Load Dataset
#
# [AG News](http://groups.di.unipi.it/~gulli/AG_corpus_of_news_articles.html) is a collection of more than 1 million news articles gathered from more than 2000 news sources by an academic news search engine. The news topic classification dataset & benchmark was first used in [Character-level Convolutional Networks for Text Classification (NIPS 2015)](https://arxiv.org/abs/1509.01626). The dataset has the text description (summary) of the news article along with some metadata. **For this project, we will use a slightly modified (cleaned up) version of this dataset**
#
# Schema:
# * Source - News publication source
# * URL - URL of the news article
# * Title - Title of the news article
# * Description - Summary description of the news article
# * Embedding - 768 dimensional embedding representation of the news article text (description)
# * Category (Label) - News category
#
# Sample row in this dataset:
# ```
# {
#    'description': 'A capsule carrying solar material from the Genesis space probe has made a crash landing at a US Air Force training facility in the US state of Utah.',
#    'id': 86273,
#    'label': 'Entertainment',
#    'source': 'Voice of America',
#    'title': 'Capsule from Genesis Space Probe Crashes in Utah Desert',
#    'Embedding': [....],
#    'url': 'http://www.sciencedaily.com/releases/2004/09/040908090621.htm'
# }
# ```

# %%
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile

DIRECTORY_NAME = "data"


def download_dataset():
    """
    Download the dataset. The zip contains three files: train.json, test.json and unlabeled.json
    """
    http_response = urlopen(DATA_URL)
    zipfile = ZipFile(BytesIO(http_response.read()))
    zipfile.extractall(path=DIRECTORY_NAME)


# Expensive operation so we should just do this once
download_dataset()

# %%
Datasets = {}

for ds in ['train', 'test']:
    with open('data/{}.json'.format(ds), 'r') as f:
        Datasets[ds] = json.load(f)
    print("Loaded Dataset {0} with {1} rows".format(ds, len(Datasets[ds])))

print("\nExample dataset row:\n")
pprint(Datasets['train'][0])
# Out:
# Loaded Dataset train with 25000 rows
# Loaded Dataset test with 50000 rows
#
# Example dataset row:
#
# {'description': 'A capsule carrying solar material from the Genesis space '
#                 'probe has made a crash landing at a US Air Force training '
#                 'facility in the US state of Utah.',
#  'embedding': [0.014944990165531635,
#                -0.012602416798472404,
#                0.022629551589488983,
#                -0.004524254705756903,
#                0.030837086960673332,
#                -0.036378033459186554,
#                -0.009855341166257858,
#                0.03661152347922325,
#                0.006519013550132513,
#                0.01946776919066906,
#                -0.04761530086398125,
#                0.022138206288218498,
#                0.032830338925123215,
#                0.04278254881501198,
#                0.02766306698322296,
#                0.02827703207731247,
#                0.017123542726039886,
#                -0.05348845198750496,
#                0.016075484454631805,
#                0.03327690437436104,
#                -0.03115227445960045,
#                -0.003829286666586995,
#                -0.025473538786172867,
#                -0.015509722754359245,
#                -0.026697050780057907,
#                0.059149134904146194,
#                0.10400382429361343,
#                0.02093622088432312,
#                0.015259518288075924,
#                -0.0015271983575075865,
#                -0.0564558282494545,
#                0.015183313749730587,
#                0.023458128795027733,
#                -0.017082693055272102,
#                1.861398059591977e-34,
#                0.010035979561507702,
#                -0.05358980968594551,
#                -0.013858268968760967,
#                0.0012140555772930384,
#                -0.004098637029528618,
#                0.008830065838992596,
#                0.06796347349882126,
#                -0.004755877889692783,
#                -0.017070347443223,
#                -0.004947595298290253,
#                -0.0005722247296944261],
#  'id': 86273,
#  'label': 'Entertainment',
#  'rank': '5',
#  'source': 'Voice of America',
#  'title': 'Capsule from Genesis Space Probe Crashes in Utah Desert',
#  'url': 'http://www.sciencedaily.com/releases/2004/09/040908090621.htm'}

# %% [markdown]
# ## Step 3: Data Quality Tests
#
# In Week 2 instruction, we learned about the importance of evaluating data quality across the ML lifecycle:
# * When building your first ML model, you often have no data and have to invest in annotation resources to get labels
# * Dataset labels can be noisy as they are collected from a variety of different sources.
# * Real world evolves (drift) and so should the datasets you’re using to train models (to make sure they evolve along with it).
#
# [Great Expectations](https://docs.greatexpectations.io/docs/) is a popular Python library for validating data in Machine Learning pipelines. It contains several built-in Expectation types to configure tests, as well as integrations with common data structures used to store datasets (e.g. Pandas dataframes, CSV files, MySQL databases etc). We will be using this library to define and run some data quality tests for our dataset. The goal and scope of the exercise here is to get you acquainted with the library and practice of testing for data quality.
#
# Useful references for this section:
# 1. Documentation: https://docs.greatexpectations.io/docs/
# 2. Using Great Expections in Jupyter: https://docs.greatexpectations.io/docs/guides/miscellaneous/how_to_quickly_explore_expectations_in_a_notebook
# 3. List of predefined Expecations: https://greatexpectations.io/expectations/
# 4. Creating custom Expecations for Pandas dataframes: https://github.com/great-expectations/great_expectations/blob/develop/docs_rtd/guides/how_to_guides/creating_and_editing_expectations/how_to_create_custom_expectations_for_pandas.rst

# %%
import pandas as pd
import great_expectations as ge
from great_expectations.dataset import PandasDataset, MetaPandasDataset

class AGNewsPandasDataset(PandasDataset):

    _data_asset_type = "AGNewsPandasDataset"

    @MetaPandasDataset.column_map_expectation
    def expect_column_string_not_null_or_empty(self, column):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the string column's value for each
        row is not NULL and not an empty string

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: (x is not None) & (len(x) > 0))

    @MetaPandasDataset.column_map_expectation
    def expect_column_embedding_dimensionality(self, column, dimension):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the embedding column's value for each
        row is not NULL and dim(embedding) == dimension

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: (len(x) == dimension) & (x is not None))

    @MetaPandasDataset.column_map_expectation
    def expect_column_in_range(self, column, range_min, range_max):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the column's value for each
        row is in range [range_min, range_max]

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: range_min <= float(x) <= range_max)

    @MetaPandasDataset.column_map_expectation
    def expect_column_embedding_unit_norm(self, column):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the embedding column's value for each
        row is not NULL and norm(embedding) == 1

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: round(np.linalg.norm(np.array(x)), 5) == 1.0)

# %%
Dataframes = {}

for ds in ['train', 'test']:
    Dataframes[ds] = ge.from_pandas(
        pd.DataFrame.from_records(Datasets[ds]),
        dataset_class=AGNewsPandasDataset
    )

# %%
for ds in ['train', 'test']:
    """
    [TO BE IMPLEMENTED]

    Expect columns in Dataframes[ds] to match the column set:
    {'id', 'source', 'title', 'url', 'rank', 'description', 'embedding', 'label'}
    """
    expected_colnames = ['id', 'source', 'title', 'url', 'rank', 'description', 'embedding', 'label']
    Dataframes[ds].expect_table_columns_to_match_ordered_list(expected_colnames)

    """
    [TO BE IMPLEMENTED]

    Expect the "id" column in Dataframes[ds] to be unique
    """
    Dataframes[ds].expect_column_values_to_be_unique(column = 'id')
    
    """
    [TO BE IMPLEMENTED]

    Expect the "description" column in Dataframes[ds] not not be null or empty
    """
    Dataframes[ds].expect_column_string_not_null_or_empty(column = 'description')

    """
    [TO BE IMPLEMENTED]

    Expect the "embedding" column in Dataframes[ds] should be non-NULL and dimensionality = 768
    (Run this after implementing `expect_column_embedding_dimensionality` above)
    """
    Dataframes[ds].expect_column_embedding_dimensionality(column = 'embedding', dimension = 768)

    """
    [TO BE IMPLEMENTED]

    Expect the "embedding" column in Dataframes[ds] should be unit norm vectors
    (Run this after implementing `expect_column_embedding_unit_norm` above)
    """
    Dataframes[ds].expect_column_embedding_unit_norm(column = 'embedding')

    """
    [TO BE IMPLEMENTED]

    Expect the "rank" column in Dataframes[ds] should be in range [1, 5]
    """
    Dataframes[ds].expect_column_in_range(column = 'rank', range_min = 1, range_max = 5)

# %%
validation_train = Dataframes["train"].validate()

pprint(validation_train)
# Out:
# {
#   "results": [
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "observed_value": [
#           "id",
#           "source",
#           "title",
#           "url",
#           "rank",
#           "description",
#           "embedding",
#           "label"
#         ]
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column_list": [
#             "id",
#             "source",
#             "title",
#             "url",
#             "rank",
#             "description",
#             "embedding",
#             "label"
#           ],
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_table_columns_to_match_ordered_list"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "id",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_values_to_be_unique"
#       }
#     },
#     {
#       "success": false,
#       "meta": {},
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 264,
#         "unexpected_percent": 1.056,
#         "unexpected_percent_total": 1.056,
#         "unexpected_percent_nonmissing": 1.056,
#         "partial_unexpected_list": [
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           ""
#         ]
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "description",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_string_not_null_or_empty"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "dimension": 768,
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_embedding_dimensionality"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_embedding_unit_norm"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 25000,
#         "missing_count": 274,
#         "missing_percent": 1.0959999999999999,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "rank",
#           "range_min": 1,
#           "range_max": 5,
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_in_range"
#       }
#     }
#   ],
#   "success": false,
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 5,
#     "unsuccessful_expectations": 1,
#     "success_percent": 83.33333333333334
#   },
#   "meta": {
#     "great_expectations_version": "0.17.2",
#     "expectation_suite_name": "default",
#     "run_id": {
#       "run_time": "2023-07-02T12:02:33.512827-04:00",
#       "run_name": null
#     },
#     "batch_kwargs": {
#       "ge_batch_id": "d9cdcd04-18f1-11ee-b40e-9e10372119bd"
#     },
#     "batch_markers": {},
#     "batch_parameters": {},
#     "validation_time": "20230702T160233.512798Z",
#     "expectation_suite_meta": {
#       "great_expectations_version": "0.17.2"
#     }
#   },
#   "evaluation_parameters": {}
# }

# %%
validation_test = Dataframes["test"].validate()

pprint(validation_test)
# Out:
# {
#   "results": [
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "observed_value": [
#           "id",
#           "source",
#           "title",
#           "url",
#           "rank",
#           "description",
#           "embedding",
#           "label"
#         ]
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column_list": [
#             "id",
#             "source",
#             "title",
#             "url",
#             "rank",
#             "description",
#             "embedding",
#             "label"
#           ],
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_table_columns_to_match_ordered_list"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "id",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_values_to_be_unique"
#       }
#     },
#     {
#       "success": false,
#       "meta": {},
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 514,
#         "unexpected_percent": 1.028,
#         "unexpected_percent_total": 1.028,
#         "unexpected_percent_nonmissing": 1.028,
#         "partial_unexpected_list": [
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           ""
#         ]
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "description",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_string_not_null_or_empty"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "dimension": 768,
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_embedding_dimensionality"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_embedding_unit_norm"
#       }
#     },
#     {
#       "success": true,
#       "meta": {},
#       "result": {
#         "element_count": 50000,
#         "missing_count": 540,
#         "missing_percent": 1.08,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "expectation_config": {
#         "kwargs": {
#           "column": "rank",
#           "range_min": 1,
#           "range_max": 5,
#           "result_format": "BASIC"
#         },
#         "meta": {},
#         "expectation_type": "expect_column_in_range"
#       }
#     }
#   ],
#   "success": false,
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 5,
#     "unsuccessful_expectations": 1,
#     "success_percent": 83.33333333333334
#   },
#   "meta": {
#     "great_expectations_version": "0.17.2",
#     "expectation_suite_name": "default",
#     "run_id": {
#       "run_time": "2023-07-02T12:02:34.024131-04:00",
#       "run_name": null
#     },
#     "batch_kwargs": {
#       "ge_batch_id": "d9d7e9c4-18f1-11ee-b40e-9e10372119bd"
#     },
#     "batch_markers": {},
#     "batch_parameters": {},
#     "validation_time": "20230702T160234.024106Z",
#     "expectation_suite_meta": {
#       "great_expectations_version": "0.17.2"
#     }
#   },
#   "evaluation_parameters": {}
# }

# %%
"""
[TO BE IMPLEMENTED]

Take a look at the results from the data validation tests. You will observe that some rows in the
training and test sets have failed the validation for the following test:

Expect the "description" column in Dataframes[ds] not not be null or empty

This is a good catch! We know that these rows in training or test set likely just add noise to the model
since it is not very relevant to ask the model to predict the category of a news article with no text.

In this step, you will filter out the rows from Datasets['train'] and Datasets['test']
and create a new Datasets_filtered object with the filtered datasets
"""

Datasets_filtered = {}
Datasets_filtered['train'] = [x for x in Datasets['train'] if (x['description'] is not None) & (len(x['description'])>0)]
Datasets_filtered['test'] = [x for x in Datasets['test'] if (x['description'] is not None) & (len(x['description'])>0)]

# %%
len(Datasets_filtered['train']), len(Datasets_filtered['test'])
# Out:
# (24736, 49486)

# %% [markdown]
# ## Step 4: Fine-grained Model Evaluation
#
# Model performance evaluation for real-world ML applications can often be complex since different stakeholders (ML engineers, product managers, sales teams) care about the impact on different dimensions. In this exercise, we will evaluate the News category classification from Week 1 in the following ways:
#
#
# * **Aggregate performance metrics**: Using standard metrics to evaluate ML model performance such as accuracy, mean squared error, BLEU scores etc (depending on the ML task) is a necessary first step, but far from sufficient. It serves to filter out models that are clearly suboptimal and reduces risk of launching bad models
#
# * **Slice-level performance metrics**: It is important to track model performance not just in aggregate but for important cohorts/slices of your traffic. For example, it is important to track the performance of your hate speech detection model not just in aggregate but for traffic from each country, language etc to understand the gaps in performance.
#
# * **Qualitative evaluations**: Behavioral tests can be helpful to root-cause individual instances of model failures and yield helpful insights to improve models

# %%
# In order to minimize variations from different model architectures & training procedures,
# we will keep the model architecture and feature sets uniform

X_train, Y_train = [], []
X_test, Y_true = [], []

for row in Datasets_filtered['train']:
    X_train.append(row['embedding'])
    Y_train.append(row['label'])

for row in Datasets_filtered['test']:
    X_test.append(row['embedding'])
    Y_true.append(row['label'])

model = LogisticRegression(
    multi_class='multinomial',
    tol=0.001,
    solver='saga',
)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

# %%
## This should be roughly in the same range as the results you got in Week 1

print("Accuracy on test set: {}".format(sklearn_metrics.accuracy_score(Y_true, Y_pred)))
# Out:
# Accuracy on test set: 0.7895364345471446

# %% [markdown]
# ## Step 4 (Part 1): Confusion Matrix and Slice-based evaluation
#
# As we saw with issues discussed around rare classes and model bias, evaluating the performance metrics at the overall dataset level is often not enough to deploy in production. Here are some commonly used axes along which ML teams commonly slice their datasets:
#
# 1. Labels (i.e. per-class performance)
# 2. Key categorical features or buckets of continuous features. E.g. a recommender system’s performance for each gender, age group.
# 3. Key traffic cohorts as defined by business value/regulatory requirements. E.g. a recommender system’s performance for newly registered users (it is important they have a good product experience else they will stop using the product)
#
# In this exercise, we will dig into per-class performance

# %%
"""
[TO BE IMPLEMENTED]

Plot a confusion matrix for the news category classification model trained above.
You should have a NxN matrix M, where
N = len(LABEL_SET)
M(i, j) = number of instances in the test set where true_label = LABEL_SET[i] and pred_label = LABEL_SET[j]

Hint: check out sklearn.metrics

"""
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)
c_matrix = confusion_matrix(Y_true, Y_pred, labels=model.classes_)

c_display = ConfusionMatrixDisplay(c_matrix, display_labels=model.classes_).plot(xticks_rotation = 'vertical')

# %%
"""
[TO BE IMPLEMENTED]

Compute the precision, recall and F1 score per-class for the test set

Hint: check out sklearn.metrics
"""
from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred))
# Out:
#                            precision    recall  f1-score   support
#
#                  Business       0.77      0.84      0.80     10675
#             Entertainment       0.77      0.65      0.70     13749
#                    Health       0.75      0.80      0.77      3932
#               Music Feeds       0.97      0.85      0.90       234
#                  Sci/Tech       0.72      0.74      0.73      7881
# Software and Developement       0.71      0.11      0.19       435
#                    Sports       0.87      0.95      0.91     12155
#                     Toons       1.00      1.00      1.00       425
#
#                  accuracy                           0.79     49486
#                 macro avg       0.82      0.74      0.75     49486
#              weighted avg       0.79      0.79      0.78     49486

# %%
import random

def confusion_matrix_errors(dataset, true_label, pred_label, class_1, class_2, num_errors=100):
    """
    [TO BE IMPLEMENTED]

    Write a function `confusion_matrix_errors` that accepts the following inputs:
    1. The test dataset
    2. True and predicted labels for each row in the dataset
    3. A pair of labels (T, P)

    And returns the `num_errors` no. of errors from the test dataset where true_label = T and pred_label = P
    """
    pairs = list(zip(true_label, pred_label))
    idx = [id for (id, pair) in enumerate(pairs) if pair[0] != pair[1]]
    errors = [dataset[i] for i in idx]
    return random.sample(errors, num_errors)


"""
[TO BE IMPLEMENTED]
Use the function implemented above to get some insights about the kind of examples that the model
is confused about for a given pair of classes
Some pairs to try out: ('Entertainment', 'Sports'), ('Health', 'Sports'), ('Business', 'Sci/Tech')
"""
for e in confusion_matrix_errors(Datasets['test'], Y_true, Y_pred, 'Entertainment', 'Sports'):
    print(e['description'])
# Out:
# British authorities shut down the pharmaceutical's only U.S. flu vaccine manufacturing facility.
# An \$800 tab raises eyebrows as New York's stylists wage a price war  upward.
# WASHINGTON Aug. 28, 2004 - Was the man in black a Democrat or a Republican? The son of the late singer Johnny Cash, who captured the hardscrabble life of those on the margins in songs such as  quot;Folsom Prison
# Every cloud...
# WASHINGTON - NASA should turn to astronauts, not robots, to repair the aging Hubble Space Telescope, an expert panel recommended on Wednesday.
# Reuters - Shares of Synopsys Inc. (SNPS.O), a\semiconductor design software maker, tumbled before the bell on\Thursday, a day after the company reported lower quarterly net\income and said results in the current quarter would be below\Wall Street estimates.
# Reuters - European aircraft maker Airbus on\Thursday criticized a U.S. move to take a fight about subsidies\to the World Trade Organization (WTO), saying it showed its\rival's unwillingness to address its own subsidies.
# Retailer Nordstrom keeps improving its operations.
# Between guard duty and patrols and shifts at the dining facility, soldiers gather to crash fast cars, play volleyball with buxom women and mimic warfare in a small trailer at Camp Liberty.
# Hydro-Quebec awarded C\$1.9 billion (\$1.5 billion) in wind-power projects to two groups on Monday in a massive push to position itself as Canada #39;s biggest buyer of the renewable energy source.
# US Treasury Secretary John Snow, left, and his German counterpart Hans Eichel, shake hands during the G20 conference of finance ministers and central bank governors in Berlin on Saturday, Nov. 20, 2004.
# Verizon Wireless said it wont oppose the Federal Communications Commissions decision to grant valuable wireless spectrum to Nextel Communications Inc.
# The BBC confirmed on Wednesday it had held talks with media companies including Time Warner, Bertelsmann and Walt Disney about its commercial subsidiary
# Bulgarian teenage star Valeri Bojinov scored twice for Italy #39;s Lecce, drawing Inter 2-2 in Serie A on Wednesday. Inter had led 2-0 after goals by Adriano and Obafemi Martins, before the 18-year-old equalized.
# Ranbaxy #39;s decision to pull its AIDS drugs off the World Health Organisation list will have little impact on the Indian firm because they form only a small part of its portfolio, analysts said on Wednesday.
# SBC Communications Inc. on Monday announced it would offer customers wireless high-speed Internet access for \$1.99 a month if they also purchased a DSL service the company delivers in partnership with Yahoo!
# There #39;s a balance to making a sequel to a successful video or computer game. The developer, at the very least, is expected to match the quality of the first game.
# PHILADELPHIA (Reuters) - Satellite television provider  DirecTV Inc. said it may take up to \$1.6 billion in charges to  write down the value of satellites it would use for  broadcasting instead of high-speed data services.
# <strong>IDF Fall '04</strong> Think different, developers told
# SYDNEY - Lawyers for the file-swapping service Kazaa argued in an Australian court yesterday that their software is analogous to the old Betamax videocassette recorders.
# Ever want to growl "shhhhhh!" to someone who's talking way too loudly on a cell phone? Rather than cause a scene, why not express your sentiments in a card? Missing Links
# Morten Gamst Pedersen scored from a swerving free kick Tuesday to earn Norway a 2-2 draw with Australia an international friendly.
# As part of its technology update program, the Defense Department has turned to two 256-processor Linux Networx Evolocity cluster supercomputers to improve complex computerized battlefield simulations.
# Wisconsin sophomore defenseman Ryan Suter has agreed to terms of a contract with the National Hockey League #39;s Nashville Predators, Suter and the Predators said Wednesday.
# Hundreds more hostages may be inside a school under siege in southern Russian than first thought, Russian officials have said. As the crisis entered its third day Friday, a spokesman
# SACRAMENTO, Calif. -- A new study says long-term exposure to pollution can cause irreversible lung damage in children. California air pollution experts are calling the study landmark news.
# all members excluding Iraq -- is nearing the 30 million barrels per day (bpd) mark, with up to a further 1.0 million
# Scientists say urinary incontinence in women can be corrected by transplanting the patient #39;s own muscle-derived stem cells into the urethra to strengthen it.
# Legal side-step fleeces punters
# KMG Chemicals Inc. ended the week on a strong note as its stock surged some 130 percent after the pesticide maker handed Wall Street fiscal first-quarter profit that more than doubled from last year.
# Reuters - U.S. factories picked up their pace in\December, capping off a year of expansion in the manufacturing\industry despite some recent signs of a downturn in employment,\a report showed on Monday.
# A 30m online map is launched telling homeowners in England and Wales what risk of flooding they face.
# CBC SPORTS ONLINE - World Anti-Doping Agency chairman Dick Pound believes the doping controversy involving American track star Marion Jones could be a watershed moment in the fight against drugs in sports.
# As the program name suggests, Computer Associates #39; new Measured Workload Pricing bases licensing costs on how much the system is sued rather than on total potential hardware capability.
# Google Inc. has quietly introduced a new search technology to help publishers sell books online, a fast-growing market dominated by Internet retailer Amazon.
# and face the challenges -- of its new status as the nation #39;s biggest cellular provider. Cingular #39;s \$41 billion merger with AT amp;T Wireless Services Inc.
# A Palestinian official, who demanded anonymity, said on Sunday that the Palestinian President Yasser Arafat is suffering liver failure and that his health condition was not improving.
# The players are all about convenience and size. They are like carrying around hundreds of CDs without the load. The iPod dominates the MP3 scene, but new competitors hope to take a bite out of Apple #39;s business.
# The nation #39;s supply of vaccine for the impending flu season took a big hit Thursday when Chiron Corp. announced it had found tainted doses in its factory.
# Health professionals and families have worked hard to turn Halloween into a day that children with diabetes can take delight in, not simply endure.
# of the country #39;s landmark leadership ballot, but has not explicitly conceded defeat to her former security chief. engagements.
# Negotiations between US Airways #39; (UAIR:Nasdaq - news - research) management and pilots continued to show progress, with the pilots union expected to give the company another proposal Friday afternoon.
# China successfully put its earth resource satellite, the third of ZY-2, into the orbit with a Chinese Long-March 4-B rocket that blasted off at 11:10 am Saturday from the Taiyuan Satellite Launch Center in north China #39;s Shanxi Province.
# Cisco Systems is aggressively targeting small and midsize businesses with a set of Ethernet switching products designed to greatly reduce the cost and complexity of operating a network.
# NEW YORK (Reuters) - The two top U.S. toymakers posted  disappointing third-quarter results on Monday and softened  expectations for the crucial holiday season, citing a wobbly  economy and cautious retailers.
# WASHINGTON -- Dell Inc. is recalling about 990,000 AC adapters used with notebook personal computers because they can overheat and cause a fire and electrical shock hazard, the Consumer Product Safety Commission said Friday.
# Tottenham, in disarray last weekend following the shock resignation of manager Jacques Santini, got their troubled campaign back on the rails last night by putting Championship opponents
# 14.2004. For a band to be eligible for induction into the Rock and Roll Hall of Fame their first release must be at least 25 years old.
# California dropped its criminal investigation of Diebold Election Systems Inc. on Tuesday, instead joining Alameda County and two electronic-voting activists in suing the Texas-based touch-screen voting machine maker.
# AP - It could be called a mechanical miracle  #151; a robot that walks on water. With inspiration from nature and some help from research at the Massachusetts Institute of Technology, a research team led by Carnegie Mellon engineering assistant professor Metin Sitti has built a tiny robot that can walk on water, much like insects known as water skimmers, water skaters, pond skaters or Jesus bugs.
# ACE Aviation Holdings Inc., the new holding company for Air Canada, enjoyed a strong debut Monday despite a mixed outlook for the stock from analysts.
# CHICAGO -- The Conference of Catholic Bishops, which aims to bring church leaders together, is once again riddled by deep division.

# %% [markdown]
# ## Step 4 (Part 2): Estimating confidence intervals with Bootstrap sampling
#
# When computing model performance metrics, the margin of error can vary a lot depending on the size of the test dataset. We are trying to estimate the model’s performance on any unseen data by empirically computing the model performance on the held-out test set, and trying to quantify the confidence intervals in this estimation: If we were to measure the model’s performance on another independently collected test dataset from the same underlying distribution, our model’s performance on this dataset is unlikely to be the same, but how different might they plausibly be?
#
# In this exercise, we will implement Bootstrap sampling to estimate the 95% confidence interval for
# overall accuracy and F1-score of the model:
#
# 1. Generate N ‘bootstrap sample’ datasets, each the same size as the original test set. Each bootstrap sample dataset is obtained by sampling instances uniformly at random from the original test set (with replacement).
# 2. On each of the bootstrap sample datasets, calculate the accuracy metric.
# 3. From Step (2), you will end up with N different accuracy values. Sort them.
# 4. The 95% confidence interval is given by the 2.5th to the 97.5th percentile among the N sorted accuracy values.

# %%
from sklearn.metrics import accuracy_score as acc

def bootstrap_accuracy_distribution(Y_true, Y_pred, N = 1000):
    """
    [TO BE IMPLEMENTED]

    Implement this function that takes two lists: Y_true, Y_pred
    and the number of bootstrap trials (N).

    It should return a list (ret) of length = N, where ret[i] = accuracy metric from i-th bootstrap sampling run
    """
    pairs = list(zip(Y_true, Y_pred))
    ret = []
    
    for n in range(N):
        data_sample = random.sample(pairs, int(len(pairs)*0.25))
        ret.append(acc(y_true = [pair[0] for pair in data_sample] , y_pred = [pair[1] for pair in data_sample]))
    
    return ret

# %%
import matplotlib.pyplot as plt
NUM_BOOTSTRAP = 1000

bs_vals = bootstrap_accuracy_distribution(Y_true, Y_pred, NUM_BOOTSTRAP)
bs_vals = sorted(bs_vals)

print("95 percent confidence interval: [{0}, {1}]".format(
    bs_vals[25],    # 2.5th percentile
    bs_vals[975]    # 97.5th percentile
))

_ = plt.hist(bs_vals, bins='auto')
plt.show()
# Out:
# 95 percent confidence interval: [0.7829601487349447, 0.7956511195537952]

# %% [markdown]
# ## Step 4 (Part 3): Minimum Functionality behavioral Tests
#
# Unit tests and integration tests play an important role in testing software for bugs, inefficiencies and potential vulnerabilities. Can we employ a similar approach to testing ML models? This exercise introduces the concept of “behavioral testing”  for machine learning models.
#
# Minimum Functionality Tests are a class of behavioral tests, and equivalents of “unit tests in software engineering” - a collection of simple examples (and labels) to check a behavior. A recommended practice is to write minimum functionality tests for highly visible/high cost potential failure modes, and for failure modes that you uncover during error analysis to guard against such failures in the future.
#
# For this exercise, we will use a popular open source library called [Checklist](https://github.com/marcotcr/checklist) to configure and run behavioral tests for our model. The goal and scope of the exercise here is to get you acquainted with the library and practice of testing for minimum functionality.
#
# Useful references:
# 1. Getting started with Checklist: https://github.com/marcotcr/checklist
# 2. Creating & Running tests with Checklist: https://github.com/marcotcr/checklist/blob/9baab717e44e216697f7ef0730ee269db9ef7d5b/notebooks/tutorials/3.%20Test%20types,%20expectation%20functions,%20running%20tests.ipynb

# %%
import checklist
from checklist.editor import Editor
from checklist.test_types import MFT
from checklist.pred_wrapper import PredictorWrapper

# Run some warmup code to get you familiar with templates in checlist
editor = Editor()
ret = editor.template('{first_name} is {a:profession} from {country}.',
                      profession=['lawyer', 'doctor', 'accountant'])
np.random.choice(ret.data, 3)
# Out:
# array(['Diana is a lawyer from Eritrea.',
#        'Ron is an accountant from Kenya.',
#        'Jack is an accountant from Saudi Arabia.'], dtype='<U67')

# %%
"""
[TO BE IMPLEMENTED]

Part 1: Data Generation for behavioral tests

1. News Source variation:
{source}: Astronomers expect the Perseid meteor shower to be one of the best versions of the shooting star events in several years
source = ['New York Times', 'Reuters', 'AP', 'Wall Street Journal', 'Quanta', 'BBC', 'BBC UK', 'Yahoo News']
labels = "Sci/Tech"

2. Company Name variation:
{company} revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
company = ['McDonalds', 'Starbucks', 'Chipotle', 'Krispy Creme', 'Unknown Company']
labels = "Sci/Tech"

3.
{disease} will come under the {mask} during the charity gala event being held on Monday at 7pm
disease = ['Breast cancer', 'Heart disease', 'Diabetes']
labels = "Health"
"""

editor = Editor()
# [TO BE IMPLEMENTED]
source = ['New York Times', 'Reuters', 'AP', 'Wall Street Journal', 'Quanta', 'BBC', 'BBC UK', 'Yahoo News']
ret = editor.template('{source}: Astronomers expect the Perseid meteor shower to be one of the best versions of the shooting star events in several years',
                      source= source, labels="Sci/Tech", save=True, nsamples=100)
# ret += editor.template(...)
company = ['McDonalds', 'Starbucks', 'Chipotle', 'Krispy Creme', 'Unknown Company']
ret += editor.template('{company} revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.',
                        company = company, labels = "Sci/Tech", save = True, nsamples = 100)

# ret += editor.template(...)
disease = ['Breast cancer', 'Heart disease', 'Diabetes']
ret += editor.template('{disease} will come under the {mask} during the charity gala event being held on Monday at 7pm',
                       disease = disease, labels = "Health", save = True, nsamples = 100)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
"""
Part 2: Test Configuration
"""

test = MFT(**ret, name='AG News MFT tests')

# %%
"""
Part 3: Test Run & Results summary
"""

def encode_and_predict(inputs):
    encoder = SentenceTransformer(
        'sentence-transformers/{model}'.format(model=EMBEDDING_MODEL)
    )
    encodings = [encoder.encode(x, normalize_embeddings=True) for x in inputs]
    return model.predict(encodings)

# wrapped_pp returns a tuple with (predictions, softmax confidences)
wrapped_pp = PredictorWrapper.wrap_predict(encode_and_predict)
test.run(wrapped_pp, overwrite=True)
test.summary()
# Out:
# Predicting 300 examples
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Test cases:      300
# Fails (rate):    100 (33.3%)
#
# Example fails:
# Business McDonalds revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
# ----
# Business Chipotle revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
# ----
# Business Krispy Creme revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
# ----

# %% [markdown]
# ## Step 5: [Optional] Advanced data quality and behavioral tests
#
# In the previous steps, you have familiarized yourself with libraries for writing data quality tests (great expectations) and behavioral tests (checkist). Take it out for a spin! A few possible extensions you can try:
#
# 1. **Model invariance behavioral tests** -- in step 4, we wrote some minimum functionality tests. Can you design some useful invariance behavioral tests?
#
# 2. **Embedding drift based data quality checks across Training/Test datasets** -- in step 3, we wrote some data quality tests. If we wanted to check for drift in embedding space between training and test data, how might we construct a data quality test for this? Hint: The distribution of euclidean distance between pairs of embeddings within the training, and between the training and test dataset should be “almost the same”

# %% [markdown]
# ## Step 6 [Optional] Examing the impact of label noise on model performance
#
# we have studied the impact of intelligently augmenting data to improve model performance. An equally important consideration is the quality of labels (both in the training and validation datasets) - label noise can lead to suboptimal performance in two ways:
# (i) noise in the validation dataset can lead us to compute model performance on incorrect ground truth labels
# (ii) noise in the training dataset can lead the model to learning incorrect correlations between input features and the ground truth label.
#
# [Cleanlab](https://docs.cleanlab.ai/stable/index.html) is a popular open source library to detect and fix label errors in datasets, by using a technique called confident learning. If you are interested to learn more, take a look at:
# * published paper: https://jair.org/index.php/jair/article/view/12125
# * blog: https://l7.curtisnorthcutt.com/confident-learning
#
# Use Cleanlab to identify labeling errors in the AG News dataset, and report any improvement in model performance. Note that
#
# Some starter tutorials/code snippets that might be helpful:
# * [Text classification tutorial](https://docs.cleanlab.ai/stable/tutorials/text.html)
# * [API Documentation](https://docs.cleanlab.ai/stable/index.html)
# * [Common example notebooks](https://github.com/cleanlab/examples)

# %%
'''
[TO BE IMPLEMENTED]

Your label noise experimentations go here

For instance, one exploration might look like the following:

import cleanlab

## Train cleanlab model
cl = cleanlab.classification.CleanLearning(
  LogisticRegression(
    multi_class='multinomial',
    tol=0.001,
    solver='saga',
))
cl.fit(<train>, <train labels>)

## Use the trained model to identify potential issues
label_issues_training = cl.find_label_issues(<train labels>, cl.predict(<train>))
label_issues_test = cl.find_label_issues(<test labels>, cl.predict(<test>))

## Use the identified issues to update the ground truth labels
## Train the new model and record performance improvements

'''
